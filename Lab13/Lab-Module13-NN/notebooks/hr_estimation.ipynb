# %% [markdown]
# # Heart Rate Estimation
#
# The goal of this exercise is to estimate heart rate from PPG and acceleration signals. We signals from the PPG-DaLiA dataset (https://archive.ics.uci.edu/ml/datasets/PPG-DaLiA). It includes PPG and acceleration signals as well as reference heart rate computed from an ECG signal.
#
# These signals were collected during various activities but we focus on two of them: sitting and walking.

# %% [markdown]
# First, we import all the packages we will need, define some global variables, and seed the random number generators.

# %%
pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: ipykernel==6.17.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from -r ../requirements.txt (line 1)) (6.17.1)
# Requirement already satisfied: ipympl in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from -r ../requirements.txt (line 2)) (0.9.8)
# Requirement already satisfied: joblib in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from -r ../requirements.txt (line 3)) (1.5.2)
# Requirement already satisfied: jupyterlab in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from -r ../requirements.txt (line 4)) (4.5.1)
# Requirement already satisfied: matplotlib in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from -r ../requirements.txt (line 5)) (3.5.2)
# Requirement already satisfied: notebook in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from -r ../requirements.txt (line 6)) (7.5.1)
# Requirement already satisfied: numpy==1.26.4 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from -r ../requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: pandas in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from -r ../requirements.txt (line 8)) (1.5.3)
# Requirement already satisfied: pytorch_lightning in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from -r ../requirements.txt (line 9)) (2.6.0)
# Requirement already satisfied: scikit-learn in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from -r ../requirements.txt (line 10)) (1.1.2)
# Requirement already satisfied: scipy in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from -r ../requirements.txt (line 11)) (1.10.1)
# Requirement already satisfied: seaborn in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from -r ../requirements.txt (line 12)) (0.11.2)
# Requirement already satisfied: tensorboard==2.11.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from -r ../requirements.txt (line 13)) (2.11.0)
# Requirement already satisfied: torch in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from -r ../requirements.txt (line 14)) (2.8.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipykernel==6.17.1->-r ../requirements.txt (line 1)) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipykernel==6.17.1->-r ../requirements.txt (line 1)) (8.18.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipykernel==6.17.1->-r ../requirements.txt (line 1)) (8.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipykernel==6.17.1->-r ../requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipykernel==6.17.1->-r ../requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: packaging in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipykernel==6.17.1->-r ../requirements.txt (line 1)) (25.0)
# Requirement already satisfied: psutil in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipykernel==6.17.1->-r ../requirements.txt (line 1)) (7.0.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipykernel==6.17.1->-r ../requirements.txt (line 1)) (27.0.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipykernel==6.17.1->-r ../requirements.txt (line 1)) (6.5.1)
# Requirement already satisfied: traitlets>=5.1.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipykernel==6.17.1->-r ../requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: absl-py>=0.4 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from tensorboard==2.11.0->-r ../requirements.txt (line 13)) (2.3.1)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from tensorboard==2.11.0->-r ../requirements.txt (line 13)) (1.76.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from tensorboard==2.11.0->-r ../requirements.txt (line 13)) (2.45.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from tensorboard==2.11.0->-r ../requirements.txt (line 13)) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from tensorboard==2.11.0->-r ../requirements.txt (line 13)) (3.9)
# Requirement already satisfied: protobuf<4,>=3.9.2 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from tensorboard==2.11.0->-r ../requirements.txt (line 13)) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from tensorboard==2.11.0->-r ../requirements.txt (line 13)) (2.32.5)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from tensorboard==2.11.0->-r ../requirements.txt (line 13)) (78.1.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from tensorboard==2.11.0->-r ../requirements.txt (line 13)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from tensorboard==2.11.0->-r ../requirements.txt (line 13)) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from tensorboard==2.11.0->-r ../requirements.txt (line 13)) (3.1.4)
# Requirement already satisfied: wheel>=0.26 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from tensorboard==2.11.0->-r ../requirements.txt (line 13)) (0.45.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard==2.11.0->-r ../requirements.txt (line 13)) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard==2.11.0->-r ../requirements.txt (line 13)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard==2.11.0->-r ../requirements.txt (line 13)) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.11.0->-r ../requirements.txt (line 13)) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from requests<3,>=2.21.0->tensorboard==2.11.0->-r ../requirements.txt (line 13)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from requests<3,>=2.21.0->tensorboard==2.11.0->-r ../requirements.txt (line 13)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from requests<3,>=2.21.0->tensorboard==2.11.0->-r ../requirements.txt (line 13)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from requests<3,>=2.21.0->tensorboard==2.11.0->-r ../requirements.txt (line 13)) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard==2.11.0->-r ../requirements.txt (line 13)) (0.6.1)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipympl->-r ../requirements.txt (line 2)) (8.1.8)
# Requirement already satisfied: pillow in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipympl->-r ../requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from matplotlib->-r ../requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from matplotlib->-r ../requirements.txt (line 5)) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from matplotlib->-r ../requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from matplotlib->-r ../requirements.txt (line 5)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from matplotlib->-r ../requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: decorator in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipython>=7.23.1->ipykernel==6.17.1->-r ../requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipython>=7.23.1->ipykernel==6.17.1->-r ../requirements.txt (line 1)) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipython>=7.23.1->ipykernel==6.17.1->-r ../requirements.txt (line 1)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipython>=7.23.1->ipykernel==6.17.1->-r ../requirements.txt (line 1)) (2.19.2)
# Requirement already satisfied: stack-data in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipython>=7.23.1->ipykernel==6.17.1->-r ../requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: typing-extensions in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipython>=7.23.1->ipykernel==6.17.1->-r ../requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: exceptiongroup in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipython>=7.23.1->ipykernel==6.17.1->-r ../requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: colorama in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipython>=7.23.1->ipykernel==6.17.1->-r ../requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl->-r ../requirements.txt (line 2)) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl->-r ../requirements.txt (line 2)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl->-r ../requirements.txt (line 2)) (3.0.16)
# Requirement already satisfied: wcwidth in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel==6.17.1->-r ../requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyterlab->-r ../requirements.txt (line 4)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyterlab->-r ../requirements.txt (line 4)) (0.28.1)
# Requirement already satisfied: importlib-metadata>=4.8.3 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyterlab->-r ../requirements.txt (line 4)) (8.7.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyterlab->-r ../requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: jupyter-core in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyterlab->-r ../requirements.txt (line 4)) (5.8.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyterlab->-r ../requirements.txt (line 4)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyterlab->-r ../requirements.txt (line 4)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyterlab->-r ../requirements.txt (line 4)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyterlab->-r ../requirements.txt (line 4)) (0.2.4)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyterlab->-r ../requirements.txt (line 4)) (2.2.1)
# Requirement already satisfied: anyio in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->-r ../requirements.txt (line 4)) (4.12.0)
# Requirement already satisfied: httpcore==1.* in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->-r ../requirements.txt (line 4)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->-r ../requirements.txt (line 4)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (0.23.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->-r ../requirements.txt (line 4)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->-r ../requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->-r ../requirements.txt (line 4)) (4.25.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from pandas->-r ../requirements.txt (line 8)) (2025.2)
# Requirement already satisfied: tqdm>=4.57.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from pytorch_lightning->-r ../requirements.txt (line 9)) (4.64.1)
# Requirement already satisfied: PyYAML>5.4 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from pytorch_lightning->-r ../requirements.txt (line 9)) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning->-r ../requirements.txt (line 9)) (2025.10.0)
# Requirement already satisfied: torchmetrics>0.7.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from pytorch_lightning->-r ../requirements.txt (line 9)) (1.8.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from pytorch_lightning->-r ../requirements.txt (line 9)) (0.15.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 10)) (3.5.0)
# Requirement already satisfied: filelock in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from torch->-r ../requirements.txt (line 14)) (3.19.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from torch->-r ../requirements.txt (line 14)) (1.14.0)
# Requirement already satisfied: networkx in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from torch->-r ../requirements.txt (line 14)) (3.2.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (25.1.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning->-r ../requirements.txt (line 9)) (3.13.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->-r ../requirements.txt (line 9)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->-r ../requirements.txt (line 9)) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->-r ../requirements.txt (line 9)) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->-r ../requirements.txt (line 9)) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->-r ../requirements.txt (line 9)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->-r ../requirements.txt (line 9)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->-r ../requirements.txt (line 9)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning->-r ../requirements.txt (line 9)) (1.22.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from importlib-metadata>=4.8.3->jupyterlab->-r ../requirements.txt (line 4)) (3.23.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel==6.17.1->-r ../requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jinja2>=3.0.3->jupyterlab->-r ../requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r ../requirements.txt (line 4)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r ../requirements.txt (line 4)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->-r ../requirements.txt (line 4)) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyter-core->jupyterlab->-r ../requirements.txt (line 4)) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyter-core->jupyterlab->-r ../requirements.txt (line 4)) (311)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (4.0.0)
# Requirement already satisfied: rfc3339-validator in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (2.21.2)
# Requirement already satisfied: six>=1.5 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from python-dateutil>=2.7->matplotlib->-r ../requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.11.0->-r ../requirements.txt (line 13)) (3.3.1)
# Requirement already satisfied: lark>=1.2.2 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from sympy>=1.13.3->torch->-r ../requirements.txt (line 14)) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (2.23)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: tzdata in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ../requirements.txt (line 4)) (2025.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.17.1->-r ../requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.17.1->-r ../requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\alexb\.conda\envs\project1-grading\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.17.1->-r ../requirements.txt (line 1)) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib widget


import copy
import functools
import itertools
import logging
import operator
import pathlib
import warnings

import IPython.display
import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pip
import pytorch_lightning as pl
import torch

DATA_FILE = pathlib.Path('../data/ppg_dalia.pkl')
LOG_DIRECTORY = pathlib.Path('../logs/hr_estimation')


# Disable logging for PyTorch Lightning to avoid too long outputs.
logging.getLogger('pytorch_lightning').setLevel(logging.ERROR)

# Seed random number generators for reproducible results.
pl.seed_everything(42)
# Out:
# Seed set to 42
# 42

# %% [markdown]
# Then, we load the PPG and acceleration signals as well as the reference heart rate. The signals are already pre-processed with the following steps:
#
# * Band-pass filtering between 0.4 and 4.0 Hz (24 - 240 bpm).
# * Resampling to 25 Hz.
#
# We also define the window length and shift length used to compute the reference heart rate.

# %%
print(DATA_FILE)
# Out:
# ..\data\ppg_dalia.pkl

# %%
import joblib
import os
import sys

FS = 25.0
WINDOW_LENGTH = 8.0
SHIFT_LENGTH = 2.0

WINDOW_SIZE = round(FS * WINDOW_LENGTH)
SHIFT_SIZE = round(FS * SHIFT_LENGTH)

DATA_FILE = r"..\data\ppg_dalia.pkl"

assert os.path.exists(DATA_FILE), f"File not found: {DATA_FILE}"

print("Python version:", sys.version)
print("Joblib version:", joblib.__version__)

# Correct loader for PPG-DaLiA
records = joblib.load(DATA_FILE, mmap_mode=None)

print(f"Type of records: {type(records)}")
print(f"Number of records: {len(records)}")

if len(records) > 0:
    print("Keys in first record:", list(records[0].keys()))

subjects = {
    record["subject"]
    for record in records
    if isinstance(record, dict) and "subject" in record
}

print(f"Window length: {WINDOW_LENGTH} s (n = {WINDOW_SIZE})")
print(f"Shift length: {SHIFT_LENGTH} s (n = {SHIFT_SIZE})")
print(f"Number of subjects: {len(subjects)}")
# Out:
# Python version: 3.9.23 (main, Jun  5 2025, 13:25:08) [MSC v.1929 64 bit (AMD64)]
# Joblib version: 1.5.2
# Type of records: <class 'list'>
# Number of records: 29
# Keys in first record: ['subject', 'activity', 'signals', 'hr']
# Window length: 8.0 s (n = 200)
# Shift length: 2.0 s (n = 50)
# Number of subjects: 15

# %% [markdown]
# Here are two examples of PPG and acceleration signals. One recorded when the subject is sitting and one recorded when the subject is walking.
#
# Each figure includes three plots: the tri-axis acceleration signals, the PPG signal, and a spectrogram of the PPG signal with the reference heart rate on top.

# %%
def plot_signals(record):
    signals = record['signals']
    hr = record['hr']

    fig, axes = plt.subplots(3, 1, sharex='all', constrained_layout=True)
    plt.suptitle(f'{record["subject"]} ({record["activity"]})')

    plt.sca(axes.flat[0])
    plt.plot(signals['time'].to_numpy(),
             signals[['acc_x', 'acc_y', 'acc_z']].to_numpy(),
             linewidth=1)
    plt.grid()
    plt.ylabel('Acceleration')

    plt.sca(axes.flat[1])
    plt.plot(signals['time'].to_numpy(), signals['ppg'].to_numpy(),
             linewidth=1)
    plt.grid()
    plt.ylabel('PPG')

    plt.sca(axes.flat[2])
    plt.specgram(signals['ppg'].to_numpy(), Fs=FS, NFFT=WINDOW_SIZE,
                 noverlap=WINDOW_SIZE - SHIFT_SIZE)
    plt.plot(hr['time'].to_numpy(), hr['hr'].to_numpy() / 60.0,
             color='tab:orange', label='Heart rate')
    plt.ylim(0.0, 4.0)
    plt.xlabel('Time [s]')
    plt.ylabel('Frequency [Hz]')
    plt.legend(loc='upper right')
    
    
plot_signals(records[0])
plot_signals(records[1])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# By zooming on the PPG signal, it is clear that walking cause a degradation in signal quality.
#
# We will try to estimate the heart rate on sliding windows of the PPG and acceleration signals. To make things easier, we use the same window length and shift between windows as the reference heart rate.
#
# So the next step is to extract sliding windows from all the records. We also extract the corresponding subject identifier for splitting the windows into subsets for training, validation, and testing.
#
# In addition, we also prepare windows that include only the PPG signal (first channel).

# %%
def extract_windows(record):
    x = record['signals'][['ppg', 'acc_x', 'acc_y', 'acc_z']].to_numpy()
    n = x.shape[0]

    windows = []
    for start in range(0, n - WINDOW_SIZE + 1, SHIFT_SIZE):
        end = start + WINDOW_SIZE
        windows.append(x[start:end].T)
    windows = np.stack(windows)
    targets = record['hr']['hr'].to_numpy()

    return windows, targets


def extract_all_windows(records):
    windows = []
    targets = []
    subjects = []
    activities = []
    for record in records:
        x, y = extract_windows(record)
        windows.append(x)
        targets.append(y)
        subjects.extend(itertools.repeat(record['subject'], x.shape[0]))
        activities.extend(itertools.repeat(record['activity'], x.shape[0]))

    windows = np.concatenate(windows, axis=0)
    targets = np.concatenate(targets)[:, None]
    subjects = np.array(subjects)
    activities = np.array(activities)

    return windows, targets, subjects, activities


ppg_acc_windows, targets, subjects, activities = extract_all_windows(records)
ppg_windows = ppg_acc_windows[:, :1, :]

print(f'Shape of PPG and accleration windows: {ppg_acc_windows.shape}')
print(f'Shape of PPG windows: {ppg_windows.shape}')
# Out:
# Shape of PPG and accleration windows: (7420, 4, 200)
# Shape of PPG windows: (7420, 1, 200)

# %% [markdown]
# We have 7420 windows with 1 or 4 channels and that each window includes 200 samples (8 seconds at 25 Hz).
#
# Next, we split the windows for training, validation, and testing by subjects. The test set includes 9 subjects, the validation set 3 subjects, and the test set 3 subjects.

# %%
def split_subjects(subjects):
    val_subjects = ('S10', 'S11', 'S12')
    test_subjects = ('S13', 'S14', 'S15')

    i_val = np.flatnonzero(np.isin(subjects, val_subjects))
    i_test = np.flatnonzero(np.isin(subjects, test_subjects))
    i_train = np.setdiff1d(np.arange(subjects.size), np.union1d(i_val, i_test))

    assert not (set(subjects[i_train]) & set(subjects[i_val]))
    assert not (set(subjects[i_train]) & set(subjects[i_test]))
    assert not (set(subjects[i_val]) & set(subjects[i_test]))
    assert (set(subjects[i_train]) | set(subjects[i_val]) | set(subjects[i_test])) == set(subjects)

    return i_train, i_val, i_test


i_train, i_val, i_test = split_subjects(subjects)

print(f'Subject used for training   : {pd.unique(subjects[i_train])}')
print(f'Subject used for validation : {pd.unique(subjects[i_val])}')
print(f'Subject used for testing    : {pd.unique(subjects[i_test])}')
# Out:
# Subject used for training   : ['S1' 'S2' 'S3' 'S4' 'S5' 'S6' 'S7' 'S8' 'S9']
# Subject used for validation : ['S10' 'S11' 'S12']
# Subject used for testing    : ['S13' 'S14' 'S15']

# %% [markdown]
# To make training more stable, we scale the windows such that they have approximately unit variance.

# %%
def compute_scaling(windows):
    sigma = np.mean(np.std(windows, axis=-1, keepdims=True), axis=0)
    return 1.0 / sigma


ppg_acc_alpha = compute_scaling(ppg_acc_windows[i_train])
ppg_acc_windows *= ppg_acc_alpha
ppg_alpha = compute_scaling(ppg_windows[i_train])
ppg_windows *= ppg_alpha

# %% [markdown]
# **Question 1**
#
# The windows are scaled but not centered. Why?

# %% [markdown]
# Now we define the convolutional neural network (CNN) we will use to estimate heart rate. It is composed of convolutional layers to extract features and dense layers to estimate heart rate. The convolutional layers can optionally include batch normalization and the dense layers dropout.

# %%
class CnnModel(torch.nn.Module):

    def __init__(self,
                 input_shape,
                 output_shape,
                 n_convolutional_layers=1,
                 kernel_size=5,
                 n_initial_channels=16,
                 use_normalization=False,
                 n_dense_layers=1,
                 n_units=128,
                 dropout=0.0):
        super().__init__()
        self.input_shape = input_shape
        self.output_shape = output_shape
        self.n_convolutional_layers = n_convolutional_layers
        self.kernel_size = kernel_size
        self.n_initial_channels = n_initial_channels
        self.use_normalization = use_normalization
        self.n_dense_layers = n_dense_layers
        self.n_units = n_units
        self.dropout = dropout
        self.layers = self._build_layers()

    @property
    def input_size(self):
        return functools.reduce(operator.mul, self.input_shape)

    @property
    def output_size(self):
        return functools.reduce(operator.mul, self.output_shape)

    def _build_layers(self):
        layers = self._build_convolutional_layers()
        layers.extend(self._build_dense_layers())
        return torch.nn.Sequential(*layers)

    def _build_convolutional_layers(self):
        layers = []

        n_output_channels = self.input_shape[0]
        for i in range(self.n_convolutional_layers):
            n_input_channels = n_output_channels
            n_output_channels = self.n_initial_channels * 2 ** i
            layers.append(torch.nn.Conv1d(
                in_channels=n_input_channels,
                out_channels=n_output_channels,
                kernel_size=self.kernel_size,
                padding='same',
            ))
            if self.use_normalization:
                layers.append(torch.nn.BatchNorm1d(n_output_channels))
            layers.append(torch.nn.ReLU())
            if i < self.n_convolutional_layers - 1:
                layers.append(torch.nn.MaxPool1d(kernel_size=2))
            else:
                layers.append(torch.nn.AdaptiveAvgPool1d(1))
        layers.append(torch.nn.Flatten())

        return layers

    def _build_dense_layers(self):
        sizes = [self.n_initial_channels
                 * 2 ** (self.n_convolutional_layers - 1)]
        sizes.extend(itertools.repeat(self.n_units, self.n_dense_layers - 1))
        sizes.append(self.output_size)

        layers = []
        for i in range(self.n_dense_layers - 1):
            layers.append(torch.nn.Linear(sizes[i], sizes[i + 1]))
            layers.append(torch.nn.ReLU())
            if 0.0 < self.dropout < 1.0:
                layers.append(torch.nn.Dropout(self.dropout))
        layers.append(torch.nn.Linear(sizes[-2], sizes[-1]))

        return layers

    def forward(self, x):
        return self.layers(x)

# %% [markdown]
# We also define a class to specify how the model should be trained and evaluated and a few utility functions. It is also here that we select the mean squared error (MSE) as the loss function to optimize the parameters. We also compute the mean absolute error (MAE) as an additional metric to monitor training.

# %%
class Regressor(pl.LightningModule):

    def __init__(self, config):
        super().__init__()
        self.save_hyperparameters()
        self.config = config
        self.model = CnnModel(**self.config['model'])
        self.example_input_array = torch.zeros((1,) + self.model.input_shape)

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), **self.config['optimizer'])

    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        return self._run_step(batch, 'train')

    def validation_step(self, batch, batch_idx):
        self._run_step(batch, 'val')

    def test_step(self, batch, batch_idx):
        self._run_step(batch, 'test')

    def predict_step(self, batch, batch_idx, dataloader_idx=0):
        x, y = batch
        return self.model(x)

    def _run_step(self, batch, subset):
        x, y = batch
        z = self.model(x)
        mse = torch.nn.functional.mse_loss(z, y)
        mae = torch.nn.functional.l1_loss(z, y)
        self.log_dict({
            f'{subset}_mse': mse,
            f'{subset}_mae': mae,
        }, on_step=False, on_epoch=True, prog_bar=True)
        return mse

    
def build_loader(*tensors, batch_size=100, shuffle=False, n_workers=0):
    dataset = torch.utils.data.TensorDataset(*map(torch.Tensor, tensors))
    return torch.utils.data.DataLoader(
        dataset=dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        num_workers=n_workers,
    )


def train_model(config, windows, targets, i_train, i_val, n_epochs, name):
    train_loader = build_loader(windows[i_train], targets[i_train], shuffle=True)
    val_loader = build_loader(windows[i_val], targets[i_val])
    regressor = Regressor(config)
    print(pl.utilities.model_summary.ModelSummary(regressor, max_depth=-1))
    
    with warnings.catch_warnings():
        warnings.simplefilter('ignore')
        trainer = pl.Trainer(
            default_root_dir=LOG_DIRECTORY,
            logger=pl.loggers.TensorBoardLogger(LOG_DIRECTORY, name),
            enable_model_summary=False,
            max_epochs=n_epochs,
        )
        trainer.fit(regressor, train_loader, val_loader)
    
    return regressor


def compute_metrics(targets, predictions):
    targets = targets.ravel()
    predictions = predictions.ravel()
    return {
        'count': targets.size,
        'mse': np.mean((targets - predictions) ** 2),
        'mae': np.mean(np.abs(targets - predictions)),
    }


def evaluate_model(model, windows, targets, i_train, i_val, i_test):
    loader = build_loader(windows, targets)
    
    with warnings.catch_warnings():
        warnings.simplefilter('ignore')
        trainer = pl.Trainer(
            default_root_dir=LOG_DIRECTORY,
            logger=False,
            enable_progress_bar=False,
            enable_model_summary=False,
        )
        predictions = trainer.predict(model, loader)
    predictions = np.vstack([p.numpy() for p in predictions])
    
    metrics = []
    for subset, indices in (('train', i_train), ('val', i_val), ('test', i_test)):
        metrics.append({
            'subset': subset,
            **compute_metrics(targets[indices], predictions[indices]),
        })
    return pd.DataFrame(metrics)

# %% [markdown]
# We also start TensorBoard to monitor training.
#
# If you prefer to view TensorBoard in a separate window, you can open http://localhost:6006/ in your web browser.

# %%
# %reload_ext tensorboard
# %tensorboard --logdir ../logs/hr_estimation --port 6006
# Out:
#       <iframe id="tensorboard-frame-1c80317fa3b1799d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-1c80317fa3b1799d");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# We are finally to define the first model configuration we will train. It includes the following layers:
#
# * Input windows (input_size = 200, input channels = 1 or 4)
# * Convolutional layer (kernel size = 5, output size = 200, output channels = 16)
# * ReLU activation
# * Max pooling (output size = 100, output channels = 16)
# * Convolutional layer (kernel size = 5, output size = 100, output channels = 32)
# * ReLU activation
# * Max pooling (output size = 50, output channels = 32)
# * Convolutional layer (kernel size = 5, output size = 50, output channels = 64)
# * ReLU activation
# * Max pooling (output size = 25, output channels = 64)
# * Convolutional layer (kernel size = 5, output size = 25, output channels = 128)
# * ReLU activation
# * Global averaging pooling (output size = 128)
# * Dense layer (output size = 128)
# * ReLU activation
# * Dense layer (output size = 128)
# * ReLU activation
# * Dense layer (output size = 1)
#
# We use the same configuration for PPG only and PPG and acceleration windows (only the input shape changes).
#
# We also define the number of epochs to use for training.

# %%
ppg_cnn_config = {
    'model': {
        'input_shape': ppg_windows.shape[1:],
        'output_shape': targets.shape[1:],
        'n_convolutional_layers': 4,
        'kernel_size': 5,
        'n_initial_channels': 16,
        'use_normalization': False,
        'n_dense_layers': 3,
        'n_units': 128,
        'dropout': 0.0,
    },
    'optimizer': {
        'lr': 0.0001,
    },
}
ppg_acc_cnn_config = copy.deepcopy(ppg_cnn_config)
ppg_acc_cnn_config['model']['input_shape'] = ppg_acc_windows.shape[1:]

n_epochs = 30

print('PPG CNN config')
IPython.display.display(ppg_cnn_config)
print()
print('PPG ACC CNN config')
IPython.display.display(ppg_acc_cnn_config)
# Out:
# PPG CNN config
# {'model': {'input_shape': (1, 200),
#   'output_shape': (1,),
#   'n_convolutional_layers': 4,
#   'kernel_size': 5,
#   'n_initial_channels': 16,
#   'use_normalization': False,
#   'n_dense_layers': 3,
#   'n_units': 128,
#   'dropout': 0.0},
#  'optimizer': {'lr': 0.0001}}
# PPG ACC CNN config
# {'model': {'input_shape': (4, 200),
#   'output_shape': (1,),
#   'n_convolutional_layers': 4,
#   'kernel_size': 5,
#   'n_initial_channels': 16,
#   'use_normalization': False,
#   'n_dense_layers': 3,
#   'n_units': 128,
#   'dropout': 0.0},
#  'optimizer': {'lr': 0.0001}}

# %% [markdown]
# We are ready to train the first two models with these configurations.

# %%
ppg_cnn = train_model(
    config=ppg_cnn_config, 
    windows=ppg_windows, 
    targets=targets, 
    i_train=i_train, 
    i_val=i_val, 
    n_epochs=n_epochs, 
    name='ppg_cnn',
)

ppg_acc_cnn = train_model(
    config=ppg_acc_cnn_config, 
    windows=ppg_acc_windows, 
    targets=targets, 
    i_train=i_train, 
    i_val=i_val, 
    n_epochs=n_epochs, 
    name='ppg_acc_cnn',
)
# Out:
#    | Name            | Type              | Params | Mode  | FLOPs  | In sizes     | Out sizes
# ------------------------------------------------------------------------------------------------------
# 0  | model           | CnnModel          | 87.2 K | train | 3.7 M  | [1, 1, 200]  | [1, 1]
# 1  | model.layers    | Sequential        | 87.2 K | train | 3.7 M  | [1, 1, 200]  | [1, 1]
# 2  | model.layers.0  | Conv1d            | 96     | train | 32.0 K | [1, 1, 200]  | [1, 16, 200]
# 3  | model.layers.1  | ReLU              | 0      | train | 0      | [1, 16, 200] | [1, 16, 200]
# 4  | model.layers.2  | MaxPool1d         | 0      | train | 0      | [1, 16, 200] | [1, 16, 100]
# 5  | model.layers.3  | Conv1d            | 2.6 K  | train | 512 K  | [1, 16, 100] | [1, 32, 100]
# 6  | model.layers.4  | ReLU              | 0      | train | 0      | [1, 32, 100] | [1, 32, 100]
# 7  | model.layers.5  | MaxPool1d         | 0      | train | 0      | [1, 32, 100] | [1, 32, 50]
# 8  | model.layers.6  | Conv1d            | 10.3 K | train | 1.0 M  | [1, 32, 50]  | [1, 64, 50]
# 9  | model.layers.7  | ReLU              | 0      | train | 0      | [1, 64, 50]  | [1, 64, 50]
# 10 | model.layers.8  | MaxPool1d         | 0      | train | 0      | [1, 64, 50]  | [1, 64, 25]
# 11 | model.layers.9  | Conv1d            | 41.1 K | train | 2.0 M  | [1, 64, 25]  | [1, 128, 25]
# 12 | model.layers.10 | ReLU              | 0      | train | 0      | [1, 128, 25] | [1, 128, 25]
# 13 | model.layers.11 | AdaptiveAvgPool1d | 0      | train | 0      | [1, 128, 25] | [1, 128, 1]
# 14 | model.layers.12 | Flatten           | 0      | train | 0      | [1, 128, 1]  | [1, 128]
# 15 | model.layers.13 | Linear            | 16.5 K | train | 32.8 K | [1, 128]     | [1, 128]
# 16 | model.layers.14 | ReLU              | 0      | train | 0      | [1, 128]     | [1, 128]
# 17 | model.layers.15 | Linear            | 16.5 K | train | 32.8 K | [1, 128]     | [1, 128]
# 18 | model.layers.16 | ReLU              | 0      | train | 0      | [1, 128]     | [1, 128]
# 19 | model.layers.17 | Linear            | 129    | train | 256    | [1, 128]     | [1, 1]
# ------------------------------------------------------------------------------------------------------
# 87.2 K    Trainable params
# 0         Non-trainable params
# 87.2 K    Total params
# 0.349     Total estimated model params size (MB)
# 20        Modules in train mode
# 0         Modules in eval mode
# 3.7 M     Total Flops
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
#    | Name            | Type              | Params | Mode  | FLOPs  | In sizes     | Out sizes
# ------------------------------------------------------------------------------------------------------
# 0  | model           | CnnModel          | 87.5 K | train | 3.8 M  | [1, 4, 200]  | [1, 1]
# 1  | model.layers    | Sequential        | 87.5 K | train | 3.8 M  | [1, 4, 200]  | [1, 1]
# 2  | model.layers.0  | Conv1d            | 336    | train | 128 K  | [1, 4, 200]  | [1, 16, 200]
# 3  | model.layers.1  | ReLU              | 0      | train | 0      | [1, 16, 200] | [1, 16, 200]
# 4  | model.layers.2  | MaxPool1d         | 0      | train | 0      | [1, 16, 200] | [1, 16, 100]
# 5  | model.layers.3  | Conv1d            | 2.6 K  | train | 512 K  | [1, 16, 100] | [1, 32, 100]
# 6  | model.layers.4  | ReLU              | 0      | train | 0      | [1, 32, 100] | [1, 32, 100]
# 7  | model.layers.5  | MaxPool1d         | 0      | train | 0      | [1, 32, 100] | [1, 32, 50]
# 8  | model.layers.6  | Conv1d            | 10.3 K | train | 1.0 M  | [1, 32, 50]  | [1, 64, 50]
# 9  | model.layers.7  | ReLU              | 0      | train | 0      | [1, 64, 50]  | [1, 64, 50]
# 10 | model.layers.8  | MaxPool1d         | 0      | train | 0      | [1, 64, 50]  | [1, 64, 25]
# 11 | model.layers.9  | Conv1d            | 41.1 K | train | 2.0 M  | [1, 64, 25]  | [1, 128, 25]
# 12 | model.layers.10 | ReLU              | 0      | train | 0      | [1, 128, 25] | [1, 128, 25]
# 13 | model.layers.11 | AdaptiveAvgPool1d | 0      | train | 0      | [1, 128, 25] | [1, 128, 1]
# 14 | model.layers.12 | Flatten           | 0      | train | 0      | [1, 128, 1]  | [1, 128]
# 15 | model.layers.13 | Linear            | 16.5 K | train | 32.8 K | [1, 128]     | [1, 128]
# 16 | model.layers.14 | ReLU              | 0      | train | 0      | [1, 128]     | [1, 128]
# 17 | model.layers.15 | Linear            | 16.5 K | train | 32.8 K | [1, 128]     | [1, 128]
# 18 | model.layers.16 | ReLU              | 0      | train | 0      | [1, 128]     | [1, 128]
# 19 | model.layers.17 | Linear            | 129    | train | 256    | [1, 128]     | [1, 1]
# ------------------------------------------------------------------------------------------------------
# 87.5 K    Trainable params
# 0         Non-trainable params
# 87.5 K    Total params
# 0.350     Total estimated model params size (MB)
# 20        Modules in train mode
# 0         Modules in eval mode
# 3.8 M     Total Flops
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]

# %% [markdown]
# **Question 2**
#
# Based on metrics shown in TensorBoard, does using the acceleration signals in addition to the PPG signal help to improve performance?

# %% [markdown]
# We plot the heart rate predicted by these two models for two records from the validation set: one where the subject is sitting and on where the subject is walking.

# %%
def apply_model(model, record, alpha):
    windows, targets = extract_windows(record)
    if alpha.shape[0] == 1:
        windows = windows[:, :1, :]
    windows *= alpha
    loader = build_loader(windows, targets)
    
    with warnings.catch_warnings():
        warnings.simplefilter('ignore')
        trainer = pl.Trainer(
            default_root_dir=LOG_DIRECTORY,
            logger=False,
            enable_progress_bar=False,
            enable_model_summary=False,
        )
        predictions = trainer.predict(model, loader)
    predictions = np.vstack([p.numpy() for p in predictions])
    
    return targets.ravel(), predictions.ravel()


def plot_results(record, models, limits=(0.0, 600.0)):
    predictions = {}
    for name, (model, alpha) in models.items():
        _, predictions[name] = apply_model(model, record, alpha)
    
    signals = record['signals']
    hr = record['hr']
    
    limits = np.array(limits)
    fig, axes = plt.subplots(2, 1, sharex='all', constrained_layout=True)
    plt.suptitle(f'{record["subject"]} ({record["activity"]})')
    plt.sca(axes.flat[0])
    plt.specgram(signals['ppg'].to_numpy(), Fs=FS, NFFT=WINDOW_SIZE,
                 noverlap=WINDOW_SIZE - SHIFT_SIZE)
    plt.plot(hr['time'].to_numpy(), hr['hr'].to_numpy() / 60.0,
             label='Reference')
    for name, prediction in predictions.items():
        plt.plot(hr['time'].to_numpy(), prediction / 60.0, label=name)
    plt.ylim(limits / 60.0)
    plt.ylabel('Frequency [Hz]')
    plt.legend(loc='upper right')
    plt.sca(axes.flat[1])
    plt.plot(hr['time'].to_numpy(), hr['hr'].to_numpy(), label='Reference')
    for name, prediction in predictions.items():
        plt.plot(hr['time'].to_numpy(), prediction, label=name)
    plt.ylim(limits)
    plt.grid()
    plt.xlabel('Time [s]')
    plt.ylabel('Heart rate [bpm]')
    plt.legend(loc='upper right')
    

models = {
    'PPG CNN': (ppg_cnn, ppg_alpha),
    'PPG ACC CNN': (ppg_acc_cnn, ppg_acc_alpha),
}

plot_results(records[21], models)
plot_results(records[22], models)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Question 3**
#
# What can you say about the predictions computed with the two models?

# %% [markdown]
# Next, we modify the configuration of the model using both PPG and acceleration to add batch normalization after each convolution layer. We do not do the same for the model using only PPG since it does not work at all.

# %%
ppg_acc_norm_cnn_config = copy.deepcopy(ppg_acc_cnn_config)
ppg_acc_norm_cnn_config['model']['use_normalization'] = True

print('PPG ACC norm CNN config')
IPython.display.display(ppg_acc_norm_cnn_config)
# Out:
# PPG ACC norm CNN config
# {'model': {'input_shape': (4, 200),
#   'output_shape': (1,),
#   'n_convolutional_layers': 4,
#   'kernel_size': 5,
#   'n_initial_channels': 16,
#   'use_normalization': True,
#   'n_dense_layers': 3,
#   'n_units': 128,
#   'dropout': 0.0},
#  'optimizer': {'lr': 0.0001}}

# %% [markdown]
# We train a model with this new configuration.

# %%
ppg_acc_norm_cnn = train_model(
    config=ppg_acc_norm_cnn_config, 
    windows=ppg_acc_windows, 
    targets=targets, 
    i_train=i_train, 
    i_val=i_val, 
    n_epochs=n_epochs, 
    name='ppg_acc_norm_cnn',
)
# Out:
#    | Name            | Type              | Params | Mode  | FLOPs  | In sizes     | Out sizes
# ------------------------------------------------------------------------------------------------------
# 0  | model           | CnnModel          | 88.0 K | train | 3.8 M  | [1, 4, 200]  | [1, 1]
# 1  | model.layers    | Sequential        | 88.0 K | train | 3.8 M  | [1, 4, 200]  | [1, 1]
# 2  | model.layers.0  | Conv1d            | 336    | train | 128 K  | [1, 4, 200]  | [1, 16, 200]
# 3  | model.layers.1  | BatchNorm1d       | 32     | train | 0      | [1, 16, 200] | [1, 16, 200]
# 4  | model.layers.2  | ReLU              | 0      | train | 0      | [1, 16, 200] | [1, 16, 200]
# 5  | model.layers.3  | MaxPool1d         | 0      | train | 0      | [1, 16, 200] | [1, 16, 100]
# 6  | model.layers.4  | Conv1d            | 2.6 K  | train | 512 K  | [1, 16, 100] | [1, 32, 100]
# 7  | model.layers.5  | BatchNorm1d       | 64     | train | 0      | [1, 32, 100] | [1, 32, 100]
# 8  | model.layers.6  | ReLU              | 0      | train | 0      | [1, 32, 100] | [1, 32, 100]
# 9  | model.layers.7  | MaxPool1d         | 0      | train | 0      | [1, 32, 100] | [1, 32, 50]
# 10 | model.layers.8  | Conv1d            | 10.3 K | train | 1.0 M  | [1, 32, 50]  | [1, 64, 50]
# 11 | model.layers.9  | BatchNorm1d       | 128    | train | 0      | [1, 64, 50]  | [1, 64, 50]
# 12 | model.layers.10 | ReLU              | 0      | train | 0      | [1, 64, 50]  | [1, 64, 50]
# 13 | model.layers.11 | MaxPool1d         | 0      | train | 0      | [1, 64, 50]  | [1, 64, 25]
# 14 | model.layers.12 | Conv1d            | 41.1 K | train | 2.0 M  | [1, 64, 25]  | [1, 128, 25]
# 15 | model.layers.13 | BatchNorm1d       | 256    | train | 0      | [1, 128, 25] | [1, 128, 25]
# 16 | model.layers.14 | ReLU              | 0      | train | 0      | [1, 128, 25] | [1, 128, 25]
# 17 | model.layers.15 | AdaptiveAvgPool1d | 0      | train | 0      | [1, 128, 25] | [1, 128, 1]
# 18 | model.layers.16 | Flatten           | 0      | train | 0      | [1, 128, 1]  | [1, 128]
# 19 | model.layers.17 | Linear            | 16.5 K | train | 32.8 K | [1, 128]     | [1, 128]
# 20 | model.layers.18 | ReLU              | 0      | train | 0      | [1, 128]     | [1, 128]
# 21 | model.layers.19 | Linear            | 16.5 K | train | 32.8 K | [1, 128]     | [1, 128]
# 22 | model.layers.20 | ReLU              | 0      | train | 0      | [1, 128]     | [1, 128]
# 23 | model.layers.21 | Linear            | 129    | train | 256    | [1, 128]     | [1, 1]
# ------------------------------------------------------------------------------------------------------
# 88.0 K    Trainable params
# 0         Non-trainable params
# 88.0 K    Total params
# 0.352     Total estimated model params size (MB)
# 24        Modules in train mode
# 0         Modules in eval mode
# 3.8 M     Total Flops
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]

# %% [markdown]
# **Question 4**
#
# What is the effect of batch normalization on the training procedure and on the perforance metrics?

# %% [markdown]
# We plot the predicted heart rate with respect to the reference for these new models (and we drop the one that did not work at all).

# %%
models = {
    'PPG ACC CNN': (ppg_acc_cnn, ppg_acc_alpha),
    'PPG ACC norm CNN': (ppg_acc_norm_cnn, ppg_acc_alpha), 
}

plot_results(records[21], models)
plot_results(records[22], models)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Question 5**
#
# Visually, is there a large difference between the CNN models with and without batch normalization on these examples?

# %% [markdown]
# Finally, we try another configuration where we add dropout after each dense layer (except the last one which is the output layer).

# %%
ppg_acc_norm_dropout_cnn_config = copy.deepcopy(ppg_acc_norm_cnn_config)
ppg_acc_norm_dropout_cnn_config['model']['dropout'] = 0.5

print('PPG ACC norm dropout CNN config')
IPython.display.display(ppg_acc_norm_dropout_cnn_config)
# Out:
# PPG ACC norm dropout CNN config
# {'model': {'input_shape': (4, 200),
#   'output_shape': (1,),
#   'n_convolutional_layers': 4,
#   'kernel_size': 5,
#   'n_initial_channels': 16,
#   'use_normalization': True,
#   'n_dense_layers': 3,
#   'n_units': 128,
#   'dropout': 0.5},
#  'optimizer': {'lr': 0.0001}}

# %% [markdown]
# And we train a new model with this configuration.

# %%
ppg_acc_norm_dropout_cnn = train_model(
    config=ppg_acc_norm_dropout_cnn_config, 
    windows=ppg_acc_windows, 
    targets=targets, 
    i_train=i_train, 
    i_val=i_val, 
    n_epochs=n_epochs, 
    name='ppg_acc_norm_dropout_cnn',
)
# Out:
#    | Name            | Type              | Params | Mode  | FLOPs  | In sizes     | Out sizes
# ------------------------------------------------------------------------------------------------------
# 0  | model           | CnnModel          | 88.0 K | train | 3.8 M  | [1, 4, 200]  | [1, 1]
# 1  | model.layers    | Sequential        | 88.0 K | train | 3.8 M  | [1, 4, 200]  | [1, 1]
# 2  | model.layers.0  | Conv1d            | 336    | train | 128 K  | [1, 4, 200]  | [1, 16, 200]
# 3  | model.layers.1  | BatchNorm1d       | 32     | train | 0      | [1, 16, 200] | [1, 16, 200]
# 4  | model.layers.2  | ReLU              | 0      | train | 0      | [1, 16, 200] | [1, 16, 200]
# 5  | model.layers.3  | MaxPool1d         | 0      | train | 0      | [1, 16, 200] | [1, 16, 100]
# 6  | model.layers.4  | Conv1d            | 2.6 K  | train | 512 K  | [1, 16, 100] | [1, 32, 100]
# 7  | model.layers.5  | BatchNorm1d       | 64     | train | 0      | [1, 32, 100] | [1, 32, 100]
# 8  | model.layers.6  | ReLU              | 0      | train | 0      | [1, 32, 100] | [1, 32, 100]
# 9  | model.layers.7  | MaxPool1d         | 0      | train | 0      | [1, 32, 100] | [1, 32, 50]
# 10 | model.layers.8  | Conv1d            | 10.3 K | train | 1.0 M  | [1, 32, 50]  | [1, 64, 50]
# 11 | model.layers.9  | BatchNorm1d       | 128    | train | 0      | [1, 64, 50]  | [1, 64, 50]
# 12 | model.layers.10 | ReLU              | 0      | train | 0      | [1, 64, 50]  | [1, 64, 50]
# 13 | model.layers.11 | MaxPool1d         | 0      | train | 0      | [1, 64, 50]  | [1, 64, 25]
# 14 | model.layers.12 | Conv1d            | 41.1 K | train | 2.0 M  | [1, 64, 25]  | [1, 128, 25]
# 15 | model.layers.13 | BatchNorm1d       | 256    | train | 0      | [1, 128, 25] | [1, 128, 25]
# 16 | model.layers.14 | ReLU              | 0      | train | 0      | [1, 128, 25] | [1, 128, 25]
# 17 | model.layers.15 | AdaptiveAvgPool1d | 0      | train | 0      | [1, 128, 25] | [1, 128, 1]
# 18 | model.layers.16 | Flatten           | 0      | train | 0      | [1, 128, 1]  | [1, 128]
# 19 | model.layers.17 | Linear            | 16.5 K | train | 32.8 K | [1, 128]     | [1, 128]
# 20 | model.layers.18 | ReLU              | 0      | train | 0      | [1, 128]     | [1, 128]
# 21 | model.layers.19 | Dropout           | 0      | train | 0      | [1, 128]     | [1, 128]
# 22 | model.layers.20 | Linear            | 16.5 K | train | 32.8 K | [1, 128]     | [1, 128]
# 23 | model.layers.21 | ReLU              | 0      | train | 0      | [1, 128]     | [1, 128]
# 24 | model.layers.22 | Dropout           | 0      | train | 0      | [1, 128]     | [1, 128]
# 25 | model.layers.23 | Linear            | 129    | train | 256    | [1, 128]     | [1, 1]
# ------------------------------------------------------------------------------------------------------
# 88.0 K    Trainable params
# 0         Non-trainable params
# 88.0 K    Total params
# 0.352     Total estimated model params size (MB)
# 26        Modules in train mode
# 0         Modules in eval mode
# 3.8 M     Total Flops
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]

# %% [markdown]
# **Question 6**
#
# Does using dropout help to reduce overfitting compare to the same model without dropout?

# %% [markdown]
# Again, we plot the predicted heart rate for two records from the validation set.

# %%
models = {
    'PPG ACC CNN': (ppg_acc_cnn, ppg_acc_alpha),
    'PPG ACC norm CNN': (ppg_acc_norm_cnn, ppg_acc_alpha),
    'PPG ACC norm dropout': (ppg_acc_norm_dropout_cnn, ppg_acc_alpha),
}

plot_results(records[21], models)
plot_results(records[22], models)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Finally, we compute performance metrics (MSE and MAE) for all models on the subsets for training, validation, and testing.

# %%
models = {
    'PPG CNN': ppg_cnn,
    'PPG ACC CNN': ppg_acc_cnn,
    'PPG ACC norm CNN': ppg_acc_norm_cnn,
    'PPG ACC norm dropout': ppg_acc_norm_dropout_cnn,
}

metrics = []
for name, model in models.items():
    if 'ACC' in name:
        windows = ppg_acc_windows
    else:
        windows = ppg_windows
    df = evaluate_model(model, windows, targets, i_train, i_val, i_test)
    df.insert(0, 'model', name)
    metrics.append(df)
metrics = pd.concat(metrics, axis=0, ignore_index=True)
metrics = metrics.set_index(['model', 'subset'])
index = metrics.index.get_level_values(0).unique()
columns = pd.MultiIndex.from_product([metrics.columns, metrics.index.get_level_values(1).unique()])
metrics = metrics.unstack().reindex(index=index, columns=columns)
IPython.display.display(metrics)
# Out:
#                      count                     mse                          \
# subset               train   val  test       train         val        test
# model
# PPG CNN               4360  1530  1530  252.993208  518.830371  199.534339
# PPG ACC CNN           4360  1530  1530  127.854039  263.425140  198.250306
# PPG ACC norm CNN      4360  1530  1530   26.237242  232.736122   71.449803
# PPG ACC norm dropout  4360  1530  1530   30.734879  242.947666   61.572759
#
#                             mae
# subset                    train        val       test
# model
# PPG CNN               12.364040  19.010172  12.442996
# PPG ACC CNN            8.779092  13.101356  12.046263
# PPG ACC norm CNN       3.765261  11.489256   6.143389
# PPG ACC norm dropout   4.059646  11.586737   5.609924

# %% [markdown]
# **Question 7**
#
# What is the best model in terms of MSE and MAE? What can you say about batch normalizaton and dropout?
