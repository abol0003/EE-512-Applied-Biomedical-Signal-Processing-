# %% [markdown]
# # PCA for Source Separation of Ventilation and Cardiovascular Activity in Electrical Impedance Tomography (EIT)
#
# ## Introduction
# In this exercise we use PCA for processing image sequences of thoracic electrical impedance tomography (EIT) signals. EIT is a non-invasive, radiation-free imaging modality which uses small alternating currents to measure bioimpedance of the thorax [1]. These measurements are then converted into image sequences of thoracic impedance changes representing ventilation (i.e., air exchange in the lungs) and cardiovascular activity (e.g., heart movement or blood volume changes in heart and lungs).
#
# In order to analyze these data it is important to properly separate ventilation and cardiovascular activity. Besides common techniques such as frequency filtering or ECG-triggered averaging, PCA can be used for separating these two sources of signals.
# The present example uses the method proposed by Deibele et al. [2] for which the block diagram is shown below:
#
# <img src="FlowChart_Deibele.png">
#
#
# ## References
#
# [1] I. Frerichs et al., “Chest electrical impedance tomography examination, data analysis, terminology, clinical use and recommendations: consensus statement of the TRanslational EIT developmeNt stuDy group,” Thorax, vol. 72, no. 1, pp. 83–93, Jan. 2017, doi: [10.1136/thoraxjnl-2016-208357](https://dx.doi.org/10.1136/thoraxjnl-2016-208357).
#
# [2] J. M. Deibele, H. Luepschen, and S. Leonhardt, “Dynamic separation of pulmonary and cardiac changes in electrical impedance tomography,” Physiological Measurement, vol. 29, no. 6, pp. S1–S14, Jun. 2008, doi: [10.1088/0967-3334/29/6/S01](https://dx.doi.org/10.1088/0967-3334/29/6/S01).

# %%
import numpy as np
from scipy.io import loadmat
from scipy.signal import filtfilt, butter
from scipy.linalg import eigh

import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
from plotly.subplots import make_subplots
init_notebook_mode(connected=True)  # initiate notebook for offline plot

from ecgdetectors import Detectors
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>

# %%
# load data
data = loadmat('EIT_Data.mat')
t = data['tEit'].flatten()[data['IdxRange'].flatten().astype(bool)]
fs = 1/np.median(np.diff(t))
imgs_eit = data['Imgs']
b, a = butter(4, np.asarray([0.1, 12]), fs=fs, btype='bandpass')
imgs_eit = filtfilt(b, a, imgs_eit, axis=-1)
imgs_eit *= 1E3  # adapt scaling for plotting

# ECG data to be used for bonus question
ecg = {'time': data['Ecg'][0][0][2], 'value': data['Ecg'][0][0][1], 'fs': data['Ecg'][0][0][3]}
ecg_range = (ecg['time'] > t[0]) & (ecg['time'] < t[-1])
ecg['time'] = ecg['time'][ecg_range]
ecg['value'] = ecg['value'][ecg_range]

# force all timings to start at zero
t -= t[0]
ecg['time'] -= ecg['time'][0]

# %%
# plot input data
fig = make_subplots(rows=1, cols=2, column_widths=[1, 2])
fig.update_layout(width=950, height=400)

fig.add_trace(go.Heatmap(z=np.std(imgs_eit, axis=-1), zmin=0, 
                         showscale=False, colorscale='magma'), row=1, col=1)
fig.update_yaxes(title='Right', showticklabels=False, autorange="reversed", row=1, col=1)
fig.update_xaxes(title='Dorsal', showticklabels=False, row=1, col=1)
fig.update_layout(title='Overall EIT Activity')

fig.add_trace(go.Scatter(x=t, y=np.nansum(imgs_eit, axis=(0, 1)), 
                         name='Overall Sum Signal', line_color='black'), row=1, col=2)
fig.update_xaxes(title='Time (s)', row=1, col=2)
fig.update_yaxes(title='Impedance Change \Delta Z (A.U.)', row=1, col=2)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id
# %%
def compute_principal_components(X):
    # perform PCA and compute principal components (pc) and eigenvalues of X
    A = np.dot(X.transpose(), X)  # covariance matrix
    [eigenvalues, eigenvectors] = eigh(A)
    pc = np.dot(X, eigenvectors)
    return pc, eigenvalues

def estimate_cardiac_frequency(s, fs):
    sign_cardiac = np.sign(s)
    # find where zero crossings occured
    index = np.where(np.diff(sign_cardiac) == 2)[0]
    # interpolate to a sub-sample resolution
    pos = index + s[index + 1] / (s[index + 1] - s[index])
    # interpolate RR interval values
    rr = np.diff(pos) / fs
    return 1/np.median(rr)

def lms(A, B):
    if B.ndim == 1:
        B = np.asmatrix(B).transpose()
    tmp = np.linalg.solve(np.dot(B.transpose(), B), B.transpose())
    return np.dot(np.dot(B, tmp), A)

# separate ventilation and cardiovascular activity using PCA
# according to the algorithm by Deibele et al., PhysMeas, 2008
# https://dx.doi.org/10.1088/0967-3334/29/6/S01
imgs_tmp = np.reshape(imgs_eit, [-1, imgs_eit.shape[-1]])
are_valid_pixels = np.all(~np.isnan(imgs_tmp), 1)
X = imgs_tmp[are_valid_pixels, :].transpose()

# first approximation (see block diagram)
X = X - np.repeat(np.reshape(np.mean(X, 0), [1, -1]), X.shape[0], 0)
PC1, lambda1 = compute_principal_components(X)
Bv = PC1[:, -1]
Xv_ = lms(X, Bv)
Xc_ = X - Xv_

# second approximation (see block diagram)
Xc_ = Xc_ - np.repeat(np.reshape(np.mean(Xc_, 0), [1, -1]), Xc_.shape[0], 0)
b, a = butter(6, np.asarray([0.92, 4.6]), fs=fs, btype='bandpass')
Xc_bp = filtfilt(b, a, Xc_, axis=0)
PC2, lambda2 = compute_principal_components(Xc_bp)
Bc_ = PC2[:, -2:]
fc = estimate_cardiac_frequency(Bc_[:, 0], fs)

# create cardiac template functions
Bc = np.hstack((Bc_, np.roll(Bc_, int(fs/fc/3), 0),
                np.roll(Bc_, -int(fs/fc/3), 0)))
Xc1 = lms(Xc_, Bc)
Xc2 = lms(Xv_, Bc)
Xc = (Xc1 + Xc2).transpose()
Xv = (Xv_ - Xc2).transpose()

# cardiovascular activity
imgs_card = np.full(imgs_tmp.shape, np.nan)
imgs_card[are_valid_pixels, :] = Xc
imgs_card = imgs_card.reshape(imgs_eit.shape)
# ventilation activity
imgs_vent = np.full(imgs_tmp.shape, np.nan)
imgs_vent[are_valid_pixels, :] = Xv
imgs_vent = imgs_vent.reshape(imgs_eit.shape)

# %%
# plot ventilation acticity
fig = make_subplots(rows=1, cols=2, column_widths=[1, 2])
fig.update_layout(width=950, height=400)

fig.add_trace(go.Heatmap(z=np.std(imgs_vent, axis=-1), zmin=0, 
                         showscale=False, colorscale='magma'), row=1, col=1)
fig.update_yaxes(title='Right', showticklabels=False, autorange="reversed", row=1, col=1)
fig.update_xaxes(title='Dorsal', showticklabels=False, row=1, col=1)
fig.update_layout(title='Ventilation Activity')

fig.add_trace(go.Scatter(x=t, y=np.nanmean(imgs_vent, axis=(0, 1)), 
                         name='Mean Signal', line_color='black'), row=1, col=2)
fig.update_xaxes(title='Time (s)', row=1, col=2)
fig.update_yaxes(title='Impedance Change \Delta Z (A.U.)', row=1, col=2)

# add example signals in ??? regions
regions = {'Region RL': ([10, 14], 'magenta'), 'Region LL': ([22, 14], 'orange')}
for reg, tmp in regions.items():
    fig.add_scatter(x=[tmp[0][0]], y=[tmp[0][1]], mode='markers', marker_symbol='square-open', 
                    marker_size=10, legendgroup=reg, marker_color=tmp[1], name=reg, row=1, col=1)
    fig.add_trace(go.Scatter(x=t, y=imgs_vent[tmp[0][1], tmp[0][0], :], legendgroup=reg, 
                             showlegend=False, name=reg, line_color=tmp[1]), row=1, col=2) 
    
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="2b8eb18e-82d4-4292-aff9-737b42b5951b" class="plotly-graph-div" style="height:400px; width:950px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2b8eb18e-82d4-4292-aff9-737b42b5951b")) {                    Plotly.newPlot(                        "2b8eb18e-82d4-4292-aff9-737b42b5951b",                        [{"colorscale":[[0.0,"#000004"],[0.1111111111111111,"#180f3d"],[0.2222222222222222,"#440f76"],[0.3333333333333333,"#721f81"],[0.4444444444444444,"#9e2f7f"],[0.5555555555555556,"#cd4071"],[0.6666666666666666,"#f1605d"],[0.7777777777777778,"#fd9668"],[0.8888888888888888,"#feca8d"],[1.0,"#fcfdbf"]],"showscale":false,"z":{"dtype":"f8","bdata":"AAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fyfKPKhe30E\u002fD39\u002fICCbQT8uFVhglXISP7SUBYanzS0\u002fOtHVAYs4Jj\u002fyaMLlnt8lPwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4f7JoER4cvDE\u002fupCH23r\u002fOD9w+DbYJgtDP4EhYUqRpTg\u002fF4i+VErjIz\u002fme+VYZoxCP3uC6mXn5EE\u002fnKfdxsmpRT\u002foQbjSO0lPP1IRKtDo+lA\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fSaUKnPxfRj+6mn5qvT05P8u1DpaezVQ\u002f8jyWjXvkVT84I1slRoVIP9VaSP5RkA4\u002fDWOEC9I6RT8ouhj45m5KP1eo1vTTMVM\u002fK4m3V0hcWT+JL2tpgGlZPwHDhhMQxUw\u002fzqSz48N3ID8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fuohaE4gaXD\u002fBpcdwOzlZPwNXcopVpNs+nYNaV5aGYD8KcDQmDSZrP3LNy+HljGo\u002fzZx8pU1+YT8C3npmfkBIP7kHkBFK0iU\u002fuG7CxFnBRD+QrY6EhDlVPzZYvYCvF14\u002f9tY9EYlwXD\u002fv8gfej81KPznUHhUEAC4\u002faNHG3+FPQD8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8dB+Z0NxtcP\u002fEXfA7p72M\u002fh1LdheHjVD+VO0jPPz9cPzp\u002fcuXY5HM\u002fWNQ7zsPsej+k9aeoxqR5P68ljBPCl3I\u002fnmSCsOHzYz+hbT\u002fG\u002fjhRPyzQi9\u002fiuyk\u002far0oLRB3SD\u002faI47i7uhYP5sIMmx1+FU\u002f23yKBe78Lz+VaKjtuD1GP0+hk0+XF0s\u002fhkBRQ6aQOT8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4f2tXV9rLTlQ\u002fa8cRX4rgZD\u002fccztN8IlgP0gv3xYWOkI\u002f0OuBGdG5cz8ZycJc57eCPwoZoyr4yoY\u002fl8nQtifxhD972mlR5mV\u002fP9vHsToSOXQ\u002fy ...

# %%
# plot cardiovascular acticity
fig = make_subplots(rows=1, cols=2, column_widths=[1, 2])
fig.update_layout(width=950, height=400)

fig.add_trace(go.Heatmap(z=np.std(imgs_card, axis=-1), zmin=0, 
                         showscale=False, colorscale='magma'), row=1, col=1)
fig.update_yaxes(title='Right', showticklabels=False, autorange="reversed", row=1, col=1)
fig.update_xaxes(title='Dorsal', showticklabels=False, row=1, col=1)
fig.update_layout(title='Cardiovascular Activity')

fig.add_trace(go.Scatter(x=t, y=np.nanmean(imgs_card, axis=(0, 1)), 
                         name='Mean Signal', line_color='black'), row=1, col=2)
fig.update_xaxes(title='Time (s)', row=1, col=2)
fig.update_yaxes(title='Impedance Change \Delta Z (A.U.)', row=1, col=2)

# add three example signals in ??? regions
regions = {'Region A': ([18, 9], 'green'), 'Region B': ([10, 15], 'blue'), 'Region C': ([23, 15], 'red')}
for reg, tmp in regions.items():
    fig.add_scatter(x=[tmp[0][0]], y=[tmp[0][1]], mode='markers', marker_symbol='square-open', 
                    marker_size=10, legendgroup=reg, marker_color=tmp[1], name=reg, row=1, col=1)
    fig.add_trace(go.Scatter(x=t, y=imgs_card[tmp[0][1], tmp[0][0], :], legendgroup=reg, 
                             showlegend=False, name=reg, line_color=tmp[1]), row=1, col=2)    
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="e8ca2a05-35be-4b38-834c-765158b3bf4e" class="plotly-graph-div" style="height:400px; width:950px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e8ca2a05-35be-4b38-834c-765158b3bf4e")) {                    Plotly.newPlot(                        "e8ca2a05-35be-4b38-834c-765158b3bf4e",                        [{"colorscale":[[0.0,"#000004"],[0.1111111111111111,"#180f3d"],[0.2222222222222222,"#440f76"],[0.3333333333333333,"#721f81"],[0.4444444444444444,"#9e2f7f"],[0.5555555555555556,"#cd4071"],[0.6666666666666666,"#f1605d"],[0.7777777777777778,"#fd9668"],[0.8888888888888888,"#feca8d"],[1.0,"#fcfdbf"]],"showscale":false,"z":{"dtype":"f8","bdata":"AAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4f64ix\u002f55xDg\u002fvuxCnrRTLD9MH6mgnLU3P8C1wmutxUE\u002f9RXouX4RPz9jsjaBxGI1PwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4f0YOYH4zXDg\u002fp19mzYngQz+HU+2bsGhDP9IOgheuKzg\u002f8B6q2cJ\u002fQD+KYVRbNSZJP2RSf8ARtkg\u002fPpLvNW+KQz+g+1NCElI\u002fP+GvKfZAKjo\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fGQcZ0xs7Mj\u002f9udtNwyFDP62lAY0SMUw\u002f7LVLjozJSj\u002f3WrIT1OlAP3VQwF1yZEY\u002fyO0n5rrJUT+gbYl24XNTP3tmQ1V1ilA\u002fKrMsMmtwSD8pI3BCYn9CP\u002favXDG1Nzs\u002fQAujw75GMj8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fJG2I6yFsIj9FC95erGIxP1nFg2PLmj4\u002f8t74peKcSj9GACRjTupRP\u002fTXxXo4Y1A\u002f9mPk8l2\u002fQz9eXbBuCcVNP82GTYR4flg\u002fV1NOnPUyXD884J6a\u002fzlZP4wGYsVCjlI\u002f7CHxkAoQSD8d1SpTJC0+Px81CBqljjk\u002fnIgGBHbqNT8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H\u002f9ZgRxpVkeP0wbntapxR4\u002fc8hrBK5yNj+Xs81EnDJGP9sP9lwzFlE\u002fBb1VhCBjVD+IBThLwyhRP1lHLYyCqUM\u002fu3IOJ7FTUj81qzMF67teP7G50Kw7XGI\u002f9+4yZolnYT8XPd5+quNaP\u002fPqltxVUVA\u002frqFkXQGXPT8N6r8oHDM+P7LtTvYMiUE\u002f\u002f+dTnTVlOT8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4f3qsvWpo1DI\u002fEk+323gwMz\u002fZ\u002frF0M4oxP\u002fCn6SQFkkE\u002fPskS8P+0Tj8dFUtmI\u002fNUP\u002f7en\u002f8e8lU\u002fp9l\u002f3mQPUD+re ...

# %% [markdown]
# # Exercise Questions
# Please provide your answers directly below each question.
#
# ---
#
# ## Question 1
# Determine the frequency of the ventilation activity (i.e., the respiratory rate), both expressed in `Hz` and `respirations/min`.

# %%
vent_signal = np.nanmean(imgs_vent, axis=(0, 1))
vent_centered = vent_signal - np.nanmean(vent_signal)
vent_window = np.hanning(vent_centered.size)
vent_fft = np.fft.rfft(vent_centered * vent_window)
vent_freqs = np.fft.rfftfreq(vent_centered.size, d=1/fs)
vent_mag = np.abs(vent_fft)
f_vent = vent_freqs[np.argmax(vent_mag)]
print(f"Ventilation rate: {f_vent:.3f} Hz = {f_vent*60:.1f} respirations/min")
# Out:
# Ventilation rate: 0.320 Hz = 19.2 respirations/min

# %% [markdown]
# ## Question 2
# Determine the frequency of the cardiovascular activity, both expressed in `Hz` and `beats/min`.

# %%
card_signal = np.nanmean(imgs_card, axis=(0, 1))
card_centered = card_signal - np.nanmean(card_signal)
card_window = np.hanning(card_centered.size)
card_fft = np.fft.rfft(card_centered * card_window)
card_freqs = np.fft.rfftfreq(card_centered.size, d=1/fs)
card_mag = np.abs(card_fft)
f_card = card_freqs[np.argmax(card_mag)]
print(f"Cardiac rate: {f_card:.3f} Hz = {f_card*60:.1f} beats/min")
# Out:
# Cardiac rate: 0.959 Hz = 57.5 beats/min

# %% [markdown]
# ## Question 3
# Determine the follwing three values:
#
# - i) the maximal amplitude of ventilation activity;
# - ii) the maximal amplitude of cardiovascular activity; and
# - iii) the ratio between i) and ii), i.e., ventilation vs cardiovascular activity.

# %%
vent_amp = float(np.nanmax(np.abs(vent_signal)))
card_amp = float(np.nanmax(np.abs(card_signal)))
ratio = vent_amp / card_amp
print(f"Max ventilation amplitude: {vent_amp:.4e} ΔZ (A.U.)")
print(f"Max cardiac amplitude:     {card_amp:.4e} ΔZ (A.U.)")
print(f"Amplitude ratio (vent/card): {ratio:.2f}")
# Out:
# Max ventilation amplitude: 7.6811e-03 ΔZ (A.U.)
# Max cardiac amplitude:     1.4271e-03 ΔZ (A.U.)
# Amplitude ratio (vent/card): 5.38

# %% [markdown]
# ## Question 4
# Determine the eigenvalues of the first three principal components resulting from the first PCA (see variable `PC1`).

# %%
top3 = lambda1[-1:-4:-1]
for idx, val in enumerate(top3, start=1):
    print(f"Eigenvalue PC{idx}: {val:.6f}")
# Out:
# Eigenvalue PC1: 107.586887
# Eigenvalue PC2: 2.111489
# Eigenvalue PC3: 0.803152

# %% [markdown]
# ## Question 5
# Similar to Question 4, determine the two most dominant frequencies for the first three principal components. <i>Note that this would lead to a total of 6 values, 2 frequencies for each of the 3 PCA components. However, for some components only one dominant frequency might be present.</i><br>
# For all 3 PCA components, which one is rather related to ventilation or cardiovascular activity?

# %%
pc_results = {}  
pc_spectra = {}  
for k in range(3):
    comp = PC1[:, -(k + 1)]  # take kth component (sorted by descending eigenvalue)
    comp_centered = comp - np.mean(comp)  # remove DC offset
    comp_window = np.hanning(comp_centered.size)  
    comp_fft = np.fft.rfft(comp_centered * comp_window)  
    comp_freqs = np.fft.rfftfreq(comp_centered.size, d=1/fs)  
    comp_mag = np.abs(comp_fft)  
    idx_sorted = np.argsort(comp_mag)[-2:][::-1]  # pick indices of two largest peaks
    pc_results[f"PC{k+1}"] = [(comp_freqs[i], comp_mag[i]) for i in idx_sorted]  # save peak info
    pc_spectra[f"PC{k+1}"] = (comp_freqs, comp_mag)  # keep entire spectrum for plotting

for pc_name, freqs in pc_results.items():
    print(pc_name)  # show component label
    for freq, mag in freqs:
        label = "ventilation" if abs(freq - f_vent) < 0.05 else "cardiovascular"  # classify peak
        print(f"  {freq:.3f} Hz (|A|={mag:.2f}) → {label}") 
print(f"If we only consider the visualtion of the spectogram we can also take into consideration for PCA2 the pic at 0.32Hz wich correspond to ventilation. \n Same for PCA3, we have a pic at 0.96Hz that correspond to cardiovascular.\n The fact is that we in reality have two peaks close to each other")

fig = make_subplots(rows=3, cols=1, shared_xaxes=False, subplot_titles=list(pc_spectra.keys()))
for row, (pc_name, (freqs, mags)) in enumerate(pc_spectra.items(), start=1):
    mask = freqs <= 5  # ne garder que les fréquences <= 5 Hz
    fig.add_trace(go.Scatter(x=freqs[mask], y=mags[mask], name=pc_name, showlegend=False),
                  row=row, col=1)
    fig.update_yaxes(title_text="|FFT|", row=row, col=1)
    fig.update_xaxes(title_text="Frequency (Hz)", range=[0, 5], row=row, col=1) #usefull signal not up to 5Hz

fig.update_layout(height=800, width=850, title="Spectra of first three principal components")
fig.show()
# Out:
# PC1
#   0.320 Hz (|A|=154.61) → ventilation
#   0.340 Hz (|A|=131.68) → ventilation
# PC2
#   0.959 Hz (|A|=14.49) → cardiovascular
#   0.979 Hz (|A|=11.30) → cardiovascular
# PC3
#   0.320 Hz (|A|=7.54) → ventilation
#   0.340 Hz (|A|=6.81) → ventilation
# If we only consider the visualtion of the spectogram we can also take into consideration for PCA2 the pic at 0.32Hz wich correspond to ventilation.
#  Same for PCA3, we have a pic at 0.96Hz that correspond to cardiovascular.
#  The fact is that we in reality have two peaks close to each other
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id
D9I7PvFbBj4P2Q7Oh3tegBADYGI67Q1AEB5zpUoooDyPxYnSOKkUdo\u002f4LYBBj8n5j\u002faZYrbQhL5P0nT0cR\u002f2wBA1v\u002ftpUhkCUB34JBx0RUHQC9W4CeN8xVALj1YSt3NKkA9G7QaXB4uQMP7Ov6yCh1AXQQDoJU6BkDXux7pAu4CQAtjf7PRuuY\u002fY5MiRYrK9z8CUkymyxoCQEwxCWTWdv ...

# %% [markdown]
# ## Question 6
# The three example signals (Regions A to C: **green, blue, red**) of cardiovascular activity show the impedance change over time.
# Can you guess the underlying anatomical structure for each of the three example signals (Regions A to C: **green, blue, red**).

# %%
print("In the plots already done above. The green region matches the heart because it shows the biggest pulsatile signal. \n The blue and red regions show lower but in phase pulses, which fits to the two lungs.")
# Out:
# In the plots already done above. The green region matches the heart because it shows the biggest pulsatile signal.
#  The blue and red regions show lower but in phase pulses, which fits to the two lungs.

# %% [markdown]
# ## Question 7 - *Bonus Question* (not graded)
# Can you detect the QRS peaks (e.g., using [`qrs = Detectors(fs).engzee_detector(ecg)`](https://github.com/berndporr/py-ecg-detectors/blob/7a1ca569190a4c17885089c97480efd114c64120/ecgdetectors.py#L277)) on the ECG signal (see variable `ecg`) and plot them together with the cardiovascular EIT activity?

# %%
detectors = Detectors(ecg['fs'])
qrs_samples = detectors.engzee_detector(ecg['value'])
qrs_times = ecg['time'][qrs_samples]
qrs_on_eit = np.interp(qrs_times, t, card_signal)

fig = go.Figure()
fig.add_trace(go.Scatter(x=t, y=card_signal, name="Mean cardiovascular"))
fig.add_trace(go.Scatter(x=qrs_times, y=qrs_on_eit, mode="markers",
                         marker=dict(color="crimson", size=8),
                         name="QRS detections (ECG)"))
fig.update_layout(title="Cardiovascular vs. ECG QRS detections",
                  xaxis_title="Time (s)",
                  yaxis_title="Impedance change ΔZ (A.U.)")
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="ae808341-98c3-43d2-88fb-74f27ac4e662" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ae808341-98c3-43d2-88fb-74f27ac4e662")) {                    Plotly.newPlot(                        "ae808341-98c3-43d2-88fb-74f27ac4e662",                        [{"name":"Mean cardiovascular","x":{"dtype":"f8","bdata":"AAAAAAAAAAAAwNVQzYWWPwCg1VDNhaY\u002fAMDOttsfsD8A8EidT4C1PwAgw4PD4Lo\u002fAKgetZsgwD8AyOuoldDCPwDouJyPgMU\u002fAAD2j8kwyD8AIMODw+DKPwA4AHf9kM0\u002fAKgetZsg0D8AOAWvmHjRPwDI66iV0NI\u002fAFSKorIo1D8A4HCcr4DVPwBwD5bM2NY\u002fAPytj+kw2D8AiEyJBonZPwAYe4Pj4No\u002fAKQZfQA53D8AaJGbvYDdPwD8v5Wa2N4\u002fAESvx1sY4D8Ain5EasTgPwDQTcF4cOE\u002fABhBPncc4j8AXhC7hcjiPwCmJzh0dOM\u002fAO72tIIg5D8ANMYxkczkPwB6la6feOU\u002fAMKIK54k5j8ACFiorNDmPwBQSyWrfOc\u002fAJY+oqko6D8A3A0fuNToPwAk3ZvGgO